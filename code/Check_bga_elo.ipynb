# %%
import bga_function  #(self-made functions)
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import statistics
import datetime
import re
import pandas as pd
import numpy as np
# import holoviews as hv
# import hvplot.pandas # adds hvplot method to pandas objects
from selenium.webdriver.common.action_chains import ActionChains
from contextlib import redirect_stdout
from bokeh.plotting import show
from bokeh.io import export_png
import os

# from selenium.webdriver.chrome.options import Options

# %%
# service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
# driver = webdriver.Chrome(service=service)
# service = webdriver.ChromeService(executable_path = r'C:\Users\Simon\Documents\GitHub\wpoc\code\chromedriver.exe')

service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %%
waiting_time = 5
# a file which comtains rows of links of BGA games
data = pd.read_csv('bga.csv')     
links = data['link']

for i in links:
    # GamePage = i
    driver.get(i)
    time.sleep(waiting_time)

    if driver.find_elements(By.XPATH, "//*[contains(text(), 'rankings have been disabled')]"):
        print("n/a", i)
    else:
        driver.find_elements(By.CLASS_NAME, 'bga-collapse-icon--reversed')[0].click()
        driver.find_elements(By.CLASS_NAME, 'bga-button-dropdown-item')[1].click()
        time.sleep(waiting_time)
        NumberRank = 3
        TopElo = driver.find_elements(By.CLASS_NAME, 'bga-ranking-entry')[NumberRank-1].find_elements(By.CLASS_NAME, 'bga-elo-label')[0].text
        print(TopElo, i)
print("finished")
# Out:
# 650 https://boardgamearena.com/gamepanel?game=sushigo
# 608 https://boardgamearena.com/gamepanel?game=sechsnimmt
# 892 https://boardgamearena.com/gamepanel?game=dobble
# 800 https://boardgamearena.com/gamepanel?game=tickettoride
# 677 https://boardgamearena.com/gamepanel?game=tickettorideeurope
# 834 https://boardgamearena.com/gamepanel?game=stoneage
# 554 https://boardgamearena.com/gamepanel?game=orleans
# 725 https://boardgamearena.com/gamepanel?game=terraformingmars
# 591 https://boardgamearena.com/gamepanel?game=fivetribes
# 496 https://boardgamearena.com/gamepanel?game=castlecombo
# 528 https://boardgamearena.com/gamepanel?game=darwinsjourney
# 562 https://boardgamearena.com/gamepanel?game=fromage
# 402 https://boardgamearena.com/gamepanel?game=revive
# 379 https://boardgamearena.com/gamepanel?game=piratesofmaracaibo
# 375 https://boardgamearena.com/gamepanel?game=kingoftokyoduel
# 234 https://boardgamearena.com/gamepanel?game=arboretum
# 636 https://boardgamearena.com/gamepanel?game=scythe
# 523 https://boardgamearena.com/gamepanel?game=yatzy
# 337 https://boardgamearena.com/gamepanel?game=lama
# 364 https://boardgamearena.com/gamepanel?game=rivervalleyglassworks
# 493 https://boardgamearena.com/gamepanel?game=pixies
# 419 https://boardgamearena.com/gamepanel?game=lostcities
# 420 https://boardgamearena.com/gamepanel?game=mountaingoats
# 365 https://boardgamearena.com/gamepanel?game=incangold
# 458 https://boardgamearena.com/gamepanel?game=cantstop
# 439 https://boardgamearena.com/gamepanel?game=captainflip
# 458 https://boardgamearena.com/gamepanel?game=cubirds
# 414 https://boardgamearena.com/gamepanel?game=sevenwondersarchitects
# 290 https://boardgamearena.com/gamepanel?game=coupcitystate
# 500 https://boardgamearena.com/gamepanel?game=catan
# 378 https://boardgamearena.com/gamepanel?game=nothanks
# 431 https://boardgamearena.com/gamepanel?game=kingoftokyo
# 489 https://boardgamearena.com/gamepanel?game=supermegaluckybox
# 510 https://boardgamearena.com/gamepanel?game=draftosaurus
# 446 https://boardgamearena.com/gamepanel?game=coltexpress
