# %%
import bga_function  #(self-made functions)
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import statistics
import datetime
import re
import pandas as pd
import numpy as np
# import holoviews as hv
# import hvplot.pandas # adds hvplot method to pandas objects
from selenium.webdriver.common.action_chains import ActionChains
from contextlib import redirect_stdout
from bokeh.plotting import show
from bokeh.io import export_png
import os

# from selenium.webdriver.chrome.options import Options

# %%
# service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
# driver = webdriver.Chrome(service=service)
# service = webdriver.ChromeService(executable_path = r'C:\Users\Simon\Documents\GitHub\wpoc\code\chromedriver.exe')

service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %%
waiting_time = 5
# a file which comtains rows of links of BGA games
data = pd.read_csv('bga.csv')     
links = data['link']

for i in links:
    # GamePage = i
    driver.get(i)
    time.sleep(waiting_time)

    if driver.find_elements(By.XPATH, "//*[contains(text(), 'rankings have been disabled')]"):
        print("other", i)
    else:
        driver.find_elements(By.CLASS_NAME, 'bga-collapse-icon--reversed')[0].click()
        driver.find_elements(By.CLASS_NAME, 'bga-button-dropdown-item')[1].click()
        time.sleep(waiting_time)
        NumberRank = 3
        TopElo = driver.find_elements(By.CLASS_NAME, 'bga-ranking-entry')[NumberRank-1].find_elements(By.CLASS_NAME, 'bga-elo-label')[0].text
        print(TopElo, i)
print("finished")
# Out:
# 707 https://boardgamearena.com/gamepanel?game=century
# 859 https://boardgamearena.com/gamepanel?game=hive
# 618 https://boardgamearena.com/gamepanel?game=bunnykingdom
# 644 https://boardgamearena.com/gamepanel?game=onitama
# 429 https://boardgamearena.com/gamepanel?game=hanamikoji
# other https://boardgamearena.com/gamepanel?game=regicide
# 601 https://boardgamearena.com/gamepanel?game=mycity
# 498 https://boardgamearena.com/gamepanel?game=tichu
# 599 https://boardgamearena.com/gamepanel?game=targi
# 697 https://boardgamearena.com/gamepanel?game=nidavellir
# 727 https://boardgamearena.com/gamepanel?game=rollforthegalaxy
# 537 https://boardgamearena.com/gamepanel?game=elgrande
# 729 https://boardgamearena.com/gamepanel?game=yokohama
# other https://boardgamearena.com/gamepanel?game=decrypto
# 651 https://boardgamearena.com/gamepanel?game=beyondthesun
# 679 https://boardgamearena.com/gamepanel?game=caverna
# 730 https://boardgamearena.com/gamepanel?game=teotihuacan
# 733 https://boardgamearena.com/gamepanel?game=warchest
# 776 https://boardgamearena.com/gamepanel?game=clansofcaledonia
# 858 https://boardgamearena.com/gamepanel?game=tzolkin
# 864 https://boardgamearena.com/gamepanel?game=puertorico
