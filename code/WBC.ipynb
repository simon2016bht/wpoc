# %%
import bga_function  #(self-made functions)
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import statistics
import datetime
import re
import pandas as pd
import numpy as np
# import holoviews as hv
# import hvplot.pandas # adds hvplot method to pandas objects
from selenium.webdriver.common.action_chains import ActionChains
from contextlib import redirect_stdout
from bokeh.plotting import show
from bokeh.io import export_png
import os

# from selenium.webdriver.chrome.options import Options

# %%
# service = webdriver.FirefoxService(executable_path = r'C:\Users\Simon\app\bin\geckodriver.exe')
# driver = webdriver.Firefox(service=service)
# "C:\Users\Simon\Documents\GitHub\wpoc\code\chromedriver.exe"
# service = webdriver.ChromeService(executable_path = r'C:\Users\Simon\Documents\GitHub\wpoc\code\chromedriver.exe')
service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
driver = webdriver.Chrome(service=service)
# # log-in  qxxxaxxx 1xxx1xxx

# %%
driver.get("https://www.boardgamers.org/yearbook24/")
time.sleep(3)
cells = driver.find_elements(By.TAG_NAME, "td")

# %%
links = []
for _ in cells:
    try:
        link = _.find_element(By.TAG_NAME, "a").get_attribute("href")
        # print(link)
        links.append(link)
    except:
        None
        # print("not found")
links = links [11:]
# links

# %%
att1 = []
att2 = []
headers = []

# %%
# len(attendance)

# %%
links[-3:]
# Out:
# ['http://www.boardgamers.org/yearbook24/WPS.html',
#  'http://www.boardgamers.org/yearbook24/WSN.html',
#  'http://www.boardgamers.org/yearbook24/WSM.html']

# %%
for _ in links:
    driver.get(_)
    try:
        text = driver.find_elements(By.CLASS_NAME, "winnerblack")[0].find_elements(By.TAG_NAME, "td")[0].text
        att1.append(text.split()[0])
    except:
        att1.append("")

    try:
        text = driver.find_elements(By.CLASS_NAME, "center.laurelists")[0].find_elements(By.TAG_NAME, "td")[0].text
        att2.append(text.split()[0])
    except:
        att2.append("")   
        
    try:
        text = driver.find_elements(By.CLASS_NAME, "GameHeader2")[0].text
        headers.append(text)
    except:
        None
    
    time.sleep(3)

# %%
for i in range(len(att1)):
    print(f'{links[i]},{att1[i]},{att2[i]},{headers[i]}')
# Out:
# http://www.boardgamers.org/yearbook24/7WS.html,141,,7 Wonders (7WS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/7WD.html,86,,7 Wonders Duel (7WD) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/878.html,19,Trimmer,,878 Vikings (878) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/775.html,40,,1775: Rebellion (775) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/8XX.html,48,Brosius,,18xx (8xx) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/930.html,,15,1930: The Golden Age of Airlines (930) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WAW.html,,21,A World at War (WAW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AoA.html,44,,Ace of Aces (AOA) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ACQ.html,81,Powers,,Acquire (ACQ) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ASZ.html,,1,Across Suez (ASZ) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ADV.html,53,,Adel Verpflichtet (ADV) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ACV.html,28,,Advanced Civilation (ACV) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AFK.html,18,,Afrika Korps (AFK) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AOR.html,18,,Age of Renaissance (AOR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AGR.html,53,,Agricola (AGR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ABN.html,43,,Air Baron (ABN) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ALH.html,104,,Alhambra (ALH) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AMR.html,37,,Amun Re (AMR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AKN.html,119,,Ark Nova (AKN) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ASK.html,12,,ASL Starter Kit (ASK) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ACS.html,66,,Atlantic Storm (ACS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ATS.html,,,Attack Sub (ATS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AUC.html,28,,Auction (AUC) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AUT.html,,19,Automobile (AUT) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/
WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/MOV.html,,58,Merchant of Venus (MOV) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/MMA.html,61,,Monsters Menace America (MMA) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/NAW.html,,4,Napoleon at Waterloo (NAW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/NVW.html,,41,Naval War (NVW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/NVG.html,,41,Navegador (NVG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ORL.html,40,,Orleans (ORL) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PZB.html,,39,Panzerblitz (PZB) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/POG.html,,19,Paths of Glory (POG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PDT.html,,33,Paydirt (PDT) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PRC.html,,93,Pirate's Cove (PRC) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PGD.html,,75,Power Grid (PGD) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PGF.html,,74,Pro Golf (PGF) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/PRO.html,,90,Puerto Rico (PRO) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/QQK.html,,29,Quirky Quarks (QQK) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/RA!.html,,150,Ra! (RA!) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/RDG.html,,181,RA: The Dice Game (RDG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/RFG.html,,45,Race for the Galaxy (RFG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ROW.html,,25,Railways of the World (ROW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ROR.html,,18,Republic of Rome (ROR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/RRY.html,,69,Robo Rally (RRY) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/ROT.html,,34,Root (ROT) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/RRR.html,,46,Russian Railroads (RRR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SAG.html,,140,Sagrada (SAG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SPG.html,,72,Saint Petersburg (SPG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SJN.html,,62,San Juan (SJN) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SFR.html,,45,Santa Fe Rails (SFR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SCY.html,,19,Scythe (SCY) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SKG.html,,18,Sekigahara (SKG) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SMW.html,,77,Small World (SMW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SBS.html,,116,Space Base (SBS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SSP.html,15,,Space Station: Phoenix (SSP) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SPD.html,,113,Splendor (SPD) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SQL.html,,19,Squad Leader (SQL) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SRM.html,,49,Star Wars: Outer Rim (SRM) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/QGB.html,,24,Star Wars: Queen's Gambit (QGB) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SWR.html,,15,Star Wars: Rebellion (SWR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SCC.html,32,,Stock Car Championship Racing (SCC) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/STA.html,,110,Stone Age (STA) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SOJ.html,11,,Storm over Jerusalem (SOJ) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/SSB.html,,24,Supeerstar Baseball (SSB) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TFM.html,,124,Terraforming Mars (TFM) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TBE.html,,30,The Barracks Emperors (TBE) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TNW.html,,47,The Napoleonic Wars (TNW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TRC.html,,22,The Russian Campaign (TRC) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/AGE.html,,23,Through the Ages (AGE) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/THA.html,,25,Thunder Alley (THA) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/T&T.html,,119,Thurn & Taxis (T&T) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TTR.html,,271,Ticket to Ride (TTR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TTN.html,,,Titan (TTN) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TT2.html,,,Titan 2-Player (TT2) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TTA.html,,66,Titan The Arena (TTA) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TAM.html,,75,Transamerica (TAM) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TWS.html,,35,Twilight Struggle (TWS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/TWR.html,,23,Twilight Struggle: Red Sea (TWR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/UNP.html,,43,Union Pacific (UNP) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/UPF.html,,28,Up Front (UPF) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/VSD.html,,78,Vegas Showdown (VSD) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/V19.html,26,,Versailles 1919 (V19) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/VIP.html,,20,Victory in the Pacific (VIP) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/VGQ.html,,35,Virgin Queen (VGQ) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WCB.html,,11,Wabash Cannonball (WCB) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WAS.html,,39,War at Sea (WAS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WOR.html,,25,War of the Ring (WOR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WWR.html,,18,Washington's War (WWR) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WAT.html,,19,Waterloo (WAT) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WNW.html,,16,Wilderness War (WNW) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WPS.html,,29,Wn, Place, & Show (WPS) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WSN.html,175,,Wingspan (WSN) WBC 2024 Event Report
# http://www.boardgamers.org/yearbook24/WSM.html,,33,Wooden Ships & Iron Men (WSM) WBC 2024 Event Report
