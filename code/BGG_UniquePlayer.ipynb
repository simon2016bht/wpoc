# %%
import bga_function #self-made functions
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import statistics
import datetime
import re
import pandas as pd
import numpy as np
# import holoviews as hv
# import hvplot.pandas # adds hvplot method to pandas objects
from selenium.webdriver.common.action_chains import ActionChains
from contextlib import redirect_stdout
# from bokeh.plotting import show
# from bokeh.io import export_png
import os

# from selenium.webdriver.chrome.options import Options

# %%
service = webdriver.ChromeService(executable_path = r'C:\Users\Simon\Documents\GitHub\wpoc\code\chromedriver.exe')
# service = webdriver.ChromeService(executable_path = r'C:\Users\chia-jung.s\Documents\GitHub\wpoc\code\chromedriver.exe')
driver = webdriver.Chrome(service=service)

# %%
waiting_time = 5
# a file which comtains rows of links of BGA games
data = pd.read_csv('bgg.csv')     
links = data['link']

# %%
# Look for games that have more than 500 unique players

UUsers = 0


for i in links[180:]:
    # GamePage = i
    # driver.get(i)
    # weight = driver.find_element(By.XPATH,'//*[@id="mainbody"]/div[2]/div/div[2]/div[2]/ng-include/div/ng-include/div/div[2]/div[2]/div[2]/gameplay-module/div/div/ul/li[4]/p/span[2]/span[1]').text
    
    try:
        id = re.findall(r'boardgame/(\d+)', i)[0]
        page = 'https://boardgamegeek.com/playstats/thing/' + id + '/2025-02'
        
    except:
        id = re.findall(r'boardgameexpansion/(\d+)', i)[0]
        page = 'https://boardgamegeek.com/playstats/thing/' + id + '/2025-02'
        
        
        
    driver.get(page)
    time.sleep(waiting_time)
    # last_page_link = driver.find_element(By.XPATH, "//a[@title='last page']")
    # UUsers = (int(last_page_link.text[1:-1])-1)*100
    try:
        last_page_link = driver.find_element(By.XPATH, "//a[@title='last page']")
        UUsers = (int(last_page_link.text[1:-1])-1)*100
        print(i,"\t", UUsers)
    except:
        print(i,"\t", "NA")
    
    
    time.sleep(waiting_time)
# Out:
# https://boardgamegeek.com/boardgame/209685/century-spice-road 	 NA
# https://boardgamegeek.com/boardgame/246761/cahoots 	 NA
# https://boardgamegeek.com/boardgame/332772/revive 	 1000
# https://boardgamegeek.com/boardgame/345972/cat-in-the-box-deluxe-edition 	 600
# https://boardgamegeek.com/boardgame/191189/aeons-end 	 NA
# https://boardgamegeek.com/boardgame/245654/railroad-ink-deep-blue-edition 	 NA
# https://boardgamegeek.com/boardgame/393672/gloomhaven-buttons-and-bugs 	 NA
# https://boardgamegeek.com/boardgame/400314/apiary 	 600
# https://boardgamegeek.com/boardgame/427624/i-am-done 	 NA
# https://boardgamegeek.com/boardgame/307002/regicide 	 NA
# https://boardgamegeek.com/boardgame/172225/exploding-kittens 	 500
# https://boardgamegeek.com/boardgame/157354/five-tribes-the-djinns-of-naqala 	 1100
# https://boardgamegeek.com/boardgame/147949/one-night-ultimate-werewolf 	 NA
# https://boardgamegeek.com/boardgame/387378/mlem-space-agency 	 600
# https://boardgamegeek.com/boardgame/246192/gizmos 	 500
# https://boardgamegeek.com/boardgame/182874/grand-austria-hotel 	 700
# https://boardgamegeek.com/boardgame/287954/azul-summer-pavilion 	 600
# https://boardgamegeek.com/boardgame/334590/for-northwood-a-solo-trick-taking-game 	 NA
# https://boardgamegeek.com/boardgame/191925/bandido 	 NA
# https://boardgamegeek.com/boardgame/277085/love-letter 	 NA
# https://boardgamegeek.com/boardgame/12/ra 	 800
# https://boardgamegeek.com/boardgame/260180/project-l 	 500
# https://boardgamegeek.com/boardgame/143741/bang-the-dice-game 	 NA
# https://boardgamegeek.com/boardgame/327778/ito 	 600
# https://boardgamegeek.com/boardgame/329873/grove-9-card-solitaire-game 	 NA
# https://boardgamegeek.com/boardgame/2397/backgammon 	 NA
# https://boardgamegeek.com/boardgame/39856/dixit 	 500
# https://boardgamegeek.com/boardgame/177736/a-feast-for-odin 	 700
# https://boardgamegeek.com/boardgame/251247/barrage 	 500
# https://boardgamegeek.com/boardgame/405537/dropolter 	 NA
# https://boardgamegeek.com/boardgame/412911/monkey-palace 	 NA
# https://boardgamegeek.com/boardgame/304783/hadrians-wall 	 NA
# https://boardgamegeek.com/boardgame/359394/my-island 	 NA
# https://boardgamegeek.com/boardgame/316377/7-wonders-second-edition 	 NA
# https://boardgamegeek.com/boardgame/420805/black-forest 	 NA
# https://boardgamegeek.com/boardgame/404431/men-nefer 	 NA
# https://boardgamegeek.com/boardgame/284435/nova-luna 	 NA
# https://boardgamegeek.com/boardgame/225694/decrypto 	 NA
# https://boardgamegeek.com/boardgame/374595/kelp-shark-vs-octopus 	 NA
# https://boardgamegeek.com/boardgame/325494/iss-vanguard 	 500
# https://boardgamegeek.com/boardgame/336986/flamecraft 	 700
# https://boardgamegeek.com/boardgame/425428/survive-the-island 	 500
# https://boardgamegeek.com/boardgame/169654/deep-sea-adventure 	 500
# https://boardgamegeek.com/boardgame/286096/tapestry 	 500
# https://boardgamegeek.com/boardgame/63888/innovation 	 NA
# https://boardgamegeek.com/boardgame/192135/too-many-bones 	 500
# https://boardgamegeek.com/boardgame/180020/virus 	 NA
# https://boardgamegeek.com/boardgame/300531/paleo 	 NA
# https://boardgamegeek.com/boardgame/161936/pandemic-legacy-season-1 	 NA
# https://boardgamegeek.com/boardgame/11/bohnanza 	 500
# https://boardgamegeek.com/boardgame/277458/kluster 	 NA
# https://boardgamegeek.com/boardgame/182028/through-the-ages-a-new-story-of-civilization 	 NA
# https://boardgamegeek.com/boardgame/399941/river-of-gold 	 500
# https://boardgamegeek.com/boardgame/198994/hero-realms 	 NA
# https://boardgamegeek.com/boardgame/167355/nemesis 	 500
# https://boardgamegeek.com/boardgame/251661/oathsworn-into-the-deepwood 	 NA
# https://boardgamegeek.com/boardgame/77423/the-lord-of-the-rings-the-card-game 	 NA
# https://boardgamegeek.com/boardgame/411255/solstis 	 NA
# https://boardgamegeek.com/boardgame/342070/thunder-road-vendetta 	 600
# https://boardgamegeek.com/boardgame/281259/the-isle-of-cats 	 600
# https://boardgamegeek.com/boardgame/249259/war-chest 	 NA
# https://boardgamegeek.com/boardgame/419195/fishing 	 600
# https://boardgamegeek.com/boardgame/34635/stone-age 	 500
# https://boardgamegeek.com/boardgame/245487/orchard-9-card-solitaire-game 	 NA
# https://boardgamegeek.com/boardgame/70919/takenoko 	 500
# https://boardgamegeek.com/boardgame/266524/parks 	 700
# https://boardgamegeek.com/boardgame/2375/sequence 	 NA
# https://boardgamegeek.com/boardgame/328871/terraforming-mars-ares-expedition 	 500
# https://boardgamegeek.com/boardgame/158600/hanamikoji 	 NA
# https://boardgamegeek.com/boardgame/117663/piraten-kapern 	 NA
# https://boardgamegeek.com/boardgame/18291/unpublished-prototype 	 NA
# https://boardgamegeek.com/boardgame/206931/encore 	 NA
# https://boardgamegeek.com/boardgame/372/schotten-totten 	 NA
# https://boardgamegeek.com/boardgame/199042/harry-potter-hogwarts-battle 	 NA
# https://boardgamegeek.com/boardgame/314491/meadow 	 500
# https://boardgamegeek.com/boardgame/355433/boop 	 NA
# https://boardgamegeek.com/boardgame/339789/welcome-to-the-moon 	 NA
# https://boardgamegeek.com/boardgame/205597/jump-drive 	 NA
# https://boardgamegeek.com/boardgame/269385/the-lord-of-the-rings-journeys-in-middle-earth 	 NA
# https://boardgamegeek.com/boardgame/251658/sprawlopolis 	 NA
# https://boardgamegeek.com/boardgame/282524/horrified 	 NA
# https://boardgamegeek.com/boardgame/359609/arkham-horror-the-card-game-revised-edition 	 NA
# https://boardgamegeek.com/boardgame/10630/memoir-44 	 NA
# https://boardgamegeek.com/boardgame/262543/wavelength 	 NA
# https://boardgamegeek.com/boardgame/219513/barenpark 	 NA
# https://boardgamegeek.com/boardgame/358690/mantis 	 NA
# https://boardgamegeek.com/boardgame/281526/the-isofarian-guard 	 NA
# https://boardgamegeek.com/boardgame/402283/courtisans 	 600
# https://boardgamegeek.com/boardgame/236457/architects-of-the-west-kingdom 	 600
# https://boardgamegeek.com/boardgame/350933/the-guild-of-merchant-explorers 	 900
# https://boardgamegeek.com/boardgame/329082/radlands 	 NA
# https://boardgamegeek.com/boardgame/403441/windmill-valley 	 NA
# https://boardgamegeek.com/boardgame/387514/stonespine-architects 	 NA
# https://boardgamegeek.com/boardgame/393307/tower-up 	 NA
# https://boardgamegeek.com/boardgame/302260/abandon-all-artichokes 	 NA
# https://boardgamegeek.com/boardgame/330592/phantom-ink 	 NA
# https://boardgamegeek.com/boardgame/383179/age-of-innovation 	 500
# https://boardgamegeek.com/boardgame/403116/next-station-paris 	 NA
# https://boardgamegeek.com/boardgame/234260/prey-another-day 	 NA
# https://boardgamegeek.com/boardgame/415147/spectacular 	 NA
# https://boardgamegeek.com/boardgame/107529/kingdom-builder 	 NA
# https://boardgamegeek.com/boardgame/377061/coffee-rush 	 500
# https://boardgamegeek.com/boardgame/181304/mysterium 	 NA
# https://boardgamegeek.com/boardgame/396790/nucleum 	 NA
# https://boardgamegeek.com/boardgame/124361/concordia 	 500
# https://boardgamegeek.com/boardgame/253664/taco-cat-goat-cheese-pizza 	 NA
# https://boardgamegeek.com/boardgame/359029/nekojima 	 NA
# https://boardgamegeek.com/boardgame/397385/pirates-of-maracaibo 	 600
# https://boardgamegeek.com/boardgame/256960/pax-pamir-second-edition 	 NA
# https://boardgamegeek.com/boardgame/121921/robinson-crusoe-adventures-on-the-cursed-island 	 NA
# https://boardgamegeek.com/boardgame/198773/codenames-pictures 	 NA
# https://boardgamegeek.com/boardgame/129437/legendary-a-marvel-deck-building-game 	 NA
# https://boardgamegeek.com/boardgame/5782/coloretto 	 NA
# https://boardgamegeek.com/boardgame/209778/magic-maze 	 NA
# https://boardgamegeek.com/boardgame/124742/android-netrunner 	 NA
# https://boardgamegeek.com/boardgame/132531/roll-for-the-galaxy 	 NA
# https://boardgamegeek.com/boardgame/15818/pickomino 	 NA
# https://boardgamegeek.com/boardgame/318977/micromacro-crime-city 	 NA
# https://boardgamegeek.com/boardgame/422484/king-of-tokyo-duel 	 600
# https://boardgamegeek.com/boardgame/160477/onitama 	 NA
# https://boardgamegeek.com/boardgame/110327/lords-of-waterdeep 	 500
# https://boardgamegeek.com/boardgame/194594/dice-forge 	 NA
# https://boardgamegeek.com/boardgame/173090/the-game 	 NA
# https://boardgamegeek.com/boardgame/43570/friday 	 NA
# https://boardgamegeek.com/boardgame/365258/world-wonders 	 NA
# https://boardgamegeek.com/boardgame/40692/small-world 	 NA
# https://boardgamegeek.com/boardgame/184921/bunny-kingdom 	 NA
# https://boardgamegeek.com/boardgame/16992/tsuro 	 NA
# https://boardgamegeek.com/boardgame/337627/voidfall 	 NA
# https://boardgamegeek.com/boardgame/402679/rock-hard-1977 	 NA
# https://boardgamegeek.com/boardgame/373577/forage-a-9-card-solitaire-game 	 NA
# https://boardgamegeek.com/boardgame/421374/landmarks 	 NA
# https://boardgamegeek.com/boardgame/290236/canvas 	 NA
# https://boardgamegeek.com/boardgame/220/high-society 	 NA
# https://boardgamegeek.com/boardgame/414107/ratjack 	 NA
# https://boardgamegeek.com/boardgame/400366/wondrous-creatures 	 500
# https://boardgamegeek.com/boardgame/413260/botanicus 	 NA
# https://boardgamegeek.com/boardgame/300753/cross-clues 	 NA
# https://boardgamegeek.com/boardgame/381249/rebel-princess 	 NA
# https://boardgamegeek.com/boardgame/205059/mansions-of-madness-second-edition 	 NA
# https://boardgamegeek.com/boardgame/193738/great-western-trail 	 NA
# https://boardgamegeek.com/boardgame/246784/cryptid 	 NA
# https://boardgamegeek.com/boardgame/46213/telestrations 	 NA
# https://boardgamegeek.com/boardgame/241590/smart10 	 NA
# https://boardgamegeek.com/boardgame/2165/pokemon-trading-card-game 	 NA
# https://boardgamegeek.com/boardgame/279537/the-search-for-planet-x 	 NA
# https://boardgamegeek.com/boardgame/351476/my-city-roll-and-build 	 NA
# https://boardgamegeek.com/boardgame/256952/zombie-kidz-evolution 	 NA
# https://boardgamegeek.com/boardgame/371932/explorers-of-navoria 	 NA
# https://boardgamegeek.com/boardgame/247763/underwater-cities 	 NA
# https://boardgamegeek.com/boardgame/158899/colt-express 	 NA
# https://boardgamegeek.com/boardgame/351040/ready-set-bet 	 NA
# https://boardgamegeek.com/boardgame/293207/eila-and-something-shiny 	 NA
# https://boardgamegeek.com/boardgame/99875/martian-dice 	 NA
# https://boardgamegeek.com/boardgame/154597/hive-pocket 	 NA
# https://boardgamegeek.com/boardgame/31260/agricola 	 NA
# https://boardgamegeek.com/boardgame/402324/eternitium 	 NA
# https://boardgamegeek.com/boardgame/387388/nanatoridori 	 NA
# https://boardgamegeek.com/boardgame/402111/kronologic-paris-1920 	 NA
# https://boardgamegeek.com/boardgame/25669/qwirkle 	 NA
# https://boardgamegeek.com/boardgame/302520/hues-and-cues 	 NA
# https://boardgamegeek.com/boardgame/320/scrabble 	 NA
# https://boardgamegeek.com/boardgame/354934/legacy-of-yu 	 NA
# https://boardgamegeek.com/boardgame/393333/galileo-galilei 	 NA
# https://boardgamegeek.com/boardgame/362976/beacon-patrol 	 NA
# https://boardgamegeek.com/boardgame/11971/cockroach-poker 	 NA
# https://boardgamegeek.com/boardgame/170216/blood-rage 	 500
# https://boardgamegeek.com/boardgame/45/perudo 	 NA
# https://boardgamegeek.com/boardgame/156129/deception-murder-in-hong-kong 	 NA
# https://boardgamegeek.com/boardgame/269207/the-taverns-of-tiefenthal 	 NA
# https://boardgamegeek.com/boardgame/295192/tinderblox 	 NA
# https://boardgamegeek.com/boardgame/353288/trekking-through-history 	 NA
# https://boardgamegeek.com/boardgame/135779/a-fake-artist-goes-to-new-york 	 NA
# https://boardgamegeek.com/boardgame/415780/lure 	 NA
# https://boardgamegeek.com/boardgame/422126/intarsia 	 NA
# https://boardgamegeek.com/boardgame/377470/sail 	 NA
# https://boardgamegeek.com/boardgame/276025/maracaibo 	 NA
# https://boardgamegeek.com/boardgame/274637/unmatched-battle-of-legends-volume-one 	 NA
# https://boardgamegeek.com/boardgame/394889/cabanga 	 NA
# https://boardgamegeek.com/boardgame/317985/beyond-the-sun 	 NA
# https://boardgamegeek.com/boardgame/393165/inferno 	 NA
# https://boardgamegeek.com/boardgame/140934/arboretum 	 500
# https://boardgamegeek.com/boardgame/363247/azul-master-chocolatier 	 NA
# https://boardgamegeek.com/boardgame/395375/art-society 	 NA
# https://boardgamegeek.com/boardgame/293014/nidavellir 	 NA
# https://boardgamegeek.com/boardgame/348096/kites 	 NA
# https://boardgamegeek.com/boardgame/368017/point-city 	 NA
# https://boardgamegeek.com/boardgame/306735/under-falling-skies 	 NA
# https://boardgamegeek.com/boardgameexpansion/368966/ark-nova-marine-worlds 	 NA
# https://boardgamegeek.com/boardgame/381278/dracula-vs-van-helsing 	 NA
# https://boardgamegeek.com/boardgame/1269/skip-bo 	 NA
# https://boardgamegeek.com/boardgame/321608/hegemony-lead-your-class-to-victory 	 NA
# https://boardgamegeek.com/boardgame/227224/the-red-cathedral 	 NA
# https://boardgamegeek.com/boardgame/2651/power-grid 	 NA
# https://boardgamegeek.com/boardgame/379078/expeditions 	 NA
# https://boardgamegeek.com/boardgame/126163/tzolkin-the-mayan-calendar 	 NA
# https://boardgamegeek.com/boardgame/128882/the-resistance-avalon 	 NA
# https://boardgamegeek.com/boardgame/296108/terraforming-mars-the-dice-game 	 NA
# https://boardgamegeek.com/boardgame/408180/shackleton-base-a-journey-to-the-moon 	 NA
# https://boardgamegeek.com/boardgame/355997/thunder-road-vendetta-maximum-chrome 	 NA
# https://boardgamegeek.com/boardgame/395623/harvest 	 NA
# https://boardgamegeek.com/boardgame/397736/hitster-guilty-pleasures 	 NA
# https://boardgamegeek.com/boardgame/430765/exit-das-spiel-adventskalender-2024-das-intergalak 	 NA
# https://boardgamegeek.com/boardgame/415836/slide 	 NA
# https://boardgamegeek.com/boardgame/376683/in-the-footsteps-of-darwin 	 NA
# https://boardgamegeek.com/boardgame/346965/azul-queens-garden 	 NA
# https://boardgamegeek.com/boardgame/265736/tiny-towns 	 NA
# https://boardgamegeek.com/boardgame/352418/fliptown 	 NA
# https://boardgamegeek.com/boardgame/6249/alhambra 	 NA
# https://boardgamegeek.com/boardgame/118048/targi 	 NA
# https://boardgamegeek.com/boardgame/359152/marvel-remix 	 NA
# https://boardgamegeek.com/boardgame/415776/kingdom-legacy-feudal-kingdom 	 500
# https://boardgamegeek.com/boardgame/271601/feed-the-kraken 	 NA
# https://boardgamegeek.com/boardgame/358124/mists-over-carcassonne 	 NA
# https://boardgamegeek.com/boardgame/269210/twice-as-clever 	 NA
# https://boardgamegeek.com/boardgame/332885/gnome-hollow 	 NA
# https://boardgamegeek.com/boardgame/255984/sleeping-gods 	 NA
# https://boardgamegeek.com/boardgame/423648/naishi 	 NA
# https://boardgamegeek.com/boardgame/300905/top-ten 	 NA
# https://boardgamegeek.com/boardgame/373636/takenokolor 	 NA
# https://boardgamegeek.com/boardgame/230253/star-realms-frontiers 	 NA
# https://boardgamegeek.com/boardgame/402024/conservas 	 NA
# https://boardgamegeek.com/boardgame/229853/teotihuacan-city-of-gods 	 NA
# https://boardgamegeek.com/boardgame/9220/saboteur 	 NA
# https://boardgamegeek.com/boardgame/1465/wizard 	 NA
# https://boardgamegeek.com/boardgame/352574/fit-to-print 	 NA
# https://boardgamegeek.com/boardgame/216132/clans-of-caledonia 	 NA
# https://boardgamegeek.com/boardgame/381356/diced-veggies 	 NA
# https://boardgamegeek.com/boardgame/227935/wonderlands-war 	 NA
# https://boardgamegeek.com/boardgame/303553/skulls-of-sedlec 	 NA
# https://boardgamegeek.com/boardgame/366161/wingspan-asia 	 NA
# https://boardgamegeek.com/boardgame/146021/eldritch-horror 	 NA
# https://boardgamegeek.com/boardgame/407318/cascadia-rolling-rivers 	 NA
# https://boardgamegeek.com/boardgame/223770/startups 	 NA
# https://boardgamegeek.com/boardgame/295374/long-shot-the-dice-game 	 NA
# https://boardgamegeek.com/boardgame/196340/yokohama 	 NA
# https://boardgamegeek.com/boardgame/93/el-grande 	 NA
# https://boardgamegeek.com/boardgame/185343/anachrony 	 NA
# https://boardgamegeek.com/boardgame/230914/carcassonne-big-box-6 	 NA
# https://boardgamegeek.com/boardgame/288513/tranquility 	 NA
# https://boardgamegeek.com/boardgame/300010/dragomino 	 NA
# https://boardgamegeek.com/boardgame/328479/living-forest 	 NA
# https://boardgamegeek.com/boardgame/334065/verdant 	 NA
# https://boardgamegeek.com/boardgame/367150/dune-war-for-arrakis 	 NA
# https://boardgamegeek.com/boardgame/362020/cosmoctopus 	 NA
# https://boardgamegeek.com/boardgame/331265/port-royal-big-box 	 NA
# https://boardgamegeek.com/boardgame/314040/pandemic-legacy-season-0 	 NA
# https://boardgamegeek.com/boardgame/378476/mycelia 	 NA
# https://boardgamegeek.com/boardgame/206915/tempel-des-schreckens 	 NA
# https://boardgamegeek.com/boardgame/399088/uno-show-em-no-mercy 	 NA
# https://boardgamegeek.com/boardgame/369880/beer-and-bread 	 NA
# https://boardgamegeek.com/boardgame/161417/red7 	 NA
# https://boardgamegeek.com/boardgame/232832/century-golem-edition 	 NA
# https://boardgamegeek.com/boardgame/405923/moonrollers 	 NA
# https://boardgamegeek.com/boardgame/156336/onirim-second-edition 	 NA
# https://boardgamegeek.com/boardgame/233078/twilight-imperium-fourth-edition 	 NA
# https://boardgamegeek.com/boardgame/422332/star-wars-the-deckbuilding-game-clone-wars-edition 	 NA
# https://boardgamegeek.com/boardgame/311322/herd-mentality 	 NA
# https://boardgamegeek.com/boardgame/143884/machi-koro 	 NA
# https://boardgamegeek.com/boardgame/219215/werewords 	 NA
# https://boardgamegeek.com/boardgame/314503/codex-naturalis 	 NA
# https://boardgamegeek.com/boardgame/300877/new-york-zoo 	 NA
# https://boardgamegeek.com/boardgame/347805/green-team-wins 	 NA
# https://boardgamegeek.com/boardgame/404041/flowers 	 NA
# https://boardgamegeek.com/boardgame/3076/puerto-rico 	 NA
# https://boardgamegeek.com/boardgame/203430/fuji-flush 	 NA
# https://boardgamegeek.com/boardgame/383499/witchcraft 	 NA
# https://boardgamegeek.com/boardgame/3955/bang 	 NA
# https://boardgamegeek.com/boardgame/147151/concept 	 NA
# https://boardgamegeek.com/boardgame/426796/stamp-swap 	 NA
# https://boardgamegeek.com/boardgame/343322/exit-the-game-advent-calendar-the-hunt-for-the-gol 	 NA
# https://boardgamegeek.com/boardgame/299252/here-to-slay 	 NA
# https://boardgamegeek.com/boardgame/169426/roll-player 	 NA
# https://boardgamegeek.com/boardgame/246900/eclipse-second-dawn-for-the-galaxy 	 NA
# https://boardgamegeek.com/boardgame/419074/fairy-ring 	 NA
# https://boardgamegeek.com/boardgame/40398/monopoly-deal-card-game 	 NA
# https://boardgamegeek.com/boardgame/302280/shifting-stones 	 NA
# https://boardgamegeek.com/boardgame/385331/creature-caravan 	 NA
# https://boardgamegeek.com/boardgame/371433/terrorscape 	 NA
# https://boardgamegeek.com/boardgame/215/tichu 	 NA
# https://boardgamegeek.com/boardgame/10400/patience 	 NA
# https://boardgamegeek.com/boardgame/268864/undaunted-normandy 	 NA
# https://boardgamegeek.com/boardgame/232361/after-the-virus 	 NA
# https://boardgamegeek.com/boardgame/409693/flatiron 	 NA
# https://boardgamegeek.com/boardgame/221965/the-fox-in-the-forest 	 NA
# https://boardgamegeek.com/boardgame/307305/bullet-love 	 NA
# https://boardgamegeek.com/boardgame/387780/rats-of-wistar 	 NA
# https://boardgamegeek.com/boardgame/410991/looot 	 NA
# https://boardgamegeek.com/boardgame/381297/unmatched-adventures-tales-to-amaze 	 NA
# https://boardgamegeek.com/boardgame/293296/splendor-marvel 	 NA
# https://boardgamegeek.com/boardgame/271460/uno-flip 	 NA
# https://boardgamegeek.com/boardgame/27225/bananagrams 	 NA
# https://boardgamegeek.com/boardgame/353152/framework 	 NA
# https://boardgamegeek.com/boardgame/382035/cursed 	 NA
# https://boardgamegeek.com/boardgame/117959/las-vegas 	 NA
# https://boardgamegeek.com/boardgame/227466/break-the-code 	 NA
# https://boardgamegeek.com/boardgame/420077/the-mandalorian-adventures 	 NA
# https://boardgamegeek.com/boardgame/380607/great-western-trail-new-zealand 	 NA
# https://boardgamegeek.com/boardgame/170042/raiders-of-the-north-sea 	 NA
# https://boardgamegeek.com/boardgame/406660/seaside 	 NA
# https://boardgamegeek.com/boardgame/62871/zombie-dice 	 NA
# https://boardgamegeek.com/boardgame/2653/survive-escape-from-atlantis 	 NA
# https://boardgamegeek.com/boardgame/386368/ezra-and-nehemiah 	 NA
# https://boardgamegeek.com/boardgame/65244/forbidden-island 	 NA
# https://boardgamegeek.com/boardgame/153938/camel-up 	 NA
# https://boardgamegeek.com/boardgame/264220/tainted-grail-the-fall-of-avalon 	 NA
# https://boardgamegeek.com/boardgame/148949/istanbul 	 NA
# https://boardgamegeek.com/boardgame/2719/connect-four 	 NA
# https://boardgamegeek.com/boardgame/328211/vegetable-stock 	 NA
# https://boardgamegeek.com/boardgame/380165/next-station-tokyo 	 NA
# https://boardgamegeek.com/boardgame/308765/praga-caput-regni 	 NA
# https://boardgamegeek.com/boardgame/378979/nusfjord-big-box 	 NA
# https://boardgamegeek.com/boardgame/12333/twilight-struggle 	 NA
# https://boardgamegeek.com/boardgame/406652/compile-main-1 	 NA
# https://boardgamegeek.com/boardgame/377793/jekyll-and-hyde-vs-scotland-yard 	 NA
# https://boardgamegeek.com/boardgame/207830/5-minute-dungeon 	 NA
# https://boardgamegeek.com/boardgame/283864/trails-of-tucana 	 NA
# https://boardgamegeek.com/boardgame/55690/kingdom-death-monster 	 NA
# https://boardgamegeek.com/boardgame/310873/carnegie 	 NA
# https://boardgamegeek.com/boardgame/308119/pax-renaissance-2nd-edition 	 NA

# %%
# try:
#     last_page_link = driver.find_element(By.XPATH, "//a[@title='last page']")
# except:
#     print(i,"\t", "NA")

# %%
# for i in links[:]:
#     # GamePage = i
#     # driver.get(i)
#     # weight = driver.find_element(By.XPATH,'//*[@id="mainbody"]/div[2]/div/div[2]/div[2]/ng-include/div/ng-include/div/div[2]/div[2]/div[2]/gameplay-module/div/div/ul/li[4]/p/span[2]/span[1]').text
#     id = re.findall(r'boardgame/(\d+)', i)[0]
#     page = 'https://boardgamegeek.com/playstats/thing/' + id + '/2025-01'
#     driver.get(page)
#     time.sleep(waiting_time)
#     last_page_link = driver.find_element(By.XPATH, "//a[@title='last page']")
#     UUsers = (int(last_page_link.text[1:-1])-1)*100
#     print(i,"\t", UUsers)
    
#     time.sleep(waiting_time)
